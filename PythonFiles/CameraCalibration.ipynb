# %%
## This is for capturing the images from the cam and safe it at location
## capture images with c and quit program with q


# Spinnaker SDK
import os
from pyspin import PySpin as spin
import sys
import keyboard
import cv2

# coding=utf-8
# =============================================================================
# Copyright (c) 2001-2021 FLIR Systems, Inc. All Rights Reserved.
#
# This software is the confidential and proprietary information of FLIR
# Integrated Imaging Solutions, Inc. ("Confidential Information"). You
# shall not disclose such Confidential Information and shall use it only in
# accordance with the terms of the license agreement you entered into
# with FLIR Integrated Imaging Solutions, Inc. (FLIR).
#
# FLIR MAKES NO REPRESENTATIONS OR WARRANTIES ABOUT THE SUITABILITY OF THE
# SOFTWARE, EITHER EXPRESSED OR IMPLIED, INCLUDING, BUT NOT LIMITED TO, THE
# IMPLIED WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PARTICULAR
# PURPOSE, OR NON-INFRINGEMENT. FLIR SHALL NOT BE LIABLE FOR ANY DAMAGES
# SUFFERED BY LICENSEE AS A RESULT OF USING, MODIFYING OR DISTRIBUTING
# THIS SOFTWARE OR ITS DERIVATIVES.
# =============================================================================
#
# Acquisition.py shows how to acquire images. It relies on
# information provided in the Enumeration example. Also, check out the
# ExceptionHandling and NodeMapInfo examples if you haven't already.
# ExceptionHandling shows the handling of standard and Spinnaker exceptions
# while NodeMapInfo explores retrieving information from various node types.
#
# This example touches on the preparation and cleanup of a camera just before
# and just after the acquisition of images. Image retrieval and conversion,
# grabbing image data, and saving images are all covered as well.
#
# Once comfortable with Acquisition, we suggest checking out
# AcquisitionMultipleCamera, NodeMapCallback, or SaveToAvi.
# AcquisitionMultipleCamera demonstrates simultaneously acquiring images from
# a number of cameras, NodeMapCallback serves as a good introduction to
# programming with callbacks and events, and SaveToAvi exhibits video creation.




## parameters

calibPictureFilename = "Test"
ROI_y = 1227
ROI_x = 584
ROI_height = 800
ROI_width = 800



def acquire_images(cam, nodemap, nodemap_tldevice):
    """
    This function acquires and saves 10 images from a device.

    :param cam: Camera to acquire images from.
    :param nodemap: Device nodemap.
    :param nodemap_tldevice: Transport layer device nodemap.
    :type cam: CameraPtr
    :type nodemap: INodeMap
    :type nodemap_tldevice: INodeMap
    :return: True if successful, False otherwise.
    :rtype: bool
    """

    print('*** IMAGE ACQUISITION ***\n')
    try:
        result = True

        # Set acquisition mode to continuous
        #
        #  *** NOTES ***
        #  Because the example acquires and saves 10 images, setting acquisition
        #  mode to continuous lets the example finish. If set to single frame
        #  or multiframe (at a lower number of images), the example would just
        #  hang. This would happen because the example has been written to
        #  acquire 10 images while the camera would have been programmed to
        #  retrieve less than that.
        #
        #  Setting the value of an enumeration node is slightly more complicated
        #  than other node types. Two nodes must be retrieved: first, the
        #  enumeration node is retrieved from the nodemap; and second, the entry
        #  node is retrieved from the enumeration node. The integer value of the
        #  entry node is then set as the new value of the enumeration node.
        #
        #  Notice that both the enumeration and the entry nodes are checked for
        #  availability and readability/writability. Enumeration nodes are
        #  generally readable and writable whereas their entry nodes are only
        #  ever readable.
        #
        #  Retrieve enumeration node from nodemap

        # In order to access the node entries, they have to be casted to a pointer type (CEnumerationPtr here)
        node_acquisition_mode = spin.CEnumerationPtr(nodemap.GetNode('AcquisitionMode'))
        if not spin.IsAvailable(node_acquisition_mode) or not spin.IsWritable(node_acquisition_mode):
            print('Unable to set acquisition mode to continuous (enum retrieval). Aborting...')
            return False

        # Retrieve entry node from enumeration node
        node_acquisition_mode_continuous = node_acquisition_mode.GetEntryByName('Continuous')
        if not spin.IsAvailable(node_acquisition_mode_continuous) or not spin.IsReadable(node_acquisition_mode_continuous):
            print('Unable to set acquisition mode to continuous (entry retrieval). Aborting...')
            return False

        # Retrieve integer value from entry node
        acquisition_mode_continuous = node_acquisition_mode_continuous.GetValue()

        # Set integer value from entry node as new value of enumeration node
        node_acquisition_mode.SetIntValue(acquisition_mode_continuous)

        print('Acquisition mode set to continuous...')

        #  Begin acquiring images
        #
        #  *** NOTES ***
        #  What happens when the camera begins acquiring images depends on the
        #  acquisition mode. Single frame captures only a single image, multi
        #  frame catures a set number of images, and continuous captures a
        #  continuous stream of images. Because the example calls for the
        #  retrieval of 10 images, continuous mode has been set.
        #
        #  *** LATER ***
        #  Image acquisition must be ended when no more images are needed.
        #cam.PixelFormat.SetValue(spin.PixelFormat_BGR8)
        cam.BeginAcquisition()

        print('Acquiring images...')

        #  Retrieve device serial number for filename
        #
        #  *** NOTES ***
        #  The device serial number is retrieved in order to keep cameras from
        #  overwriting one another. Grabbing image IDs could also accomplish
        #  this.
        device_serial_number = ''
        node_device_serial_number = spin.CStringPtr(nodemap_tldevice.GetNode('DeviceSerialNumber'))
        if spin.IsAvailable(node_device_serial_number) and spin.IsReadable(node_device_serial_number):
            device_serial_number = node_device_serial_number.GetValue()
            print('Device serial number retrieved as %s...' % device_serial_number)

        # Retrieve, convert, and save images
        ## for continous tream: change this into while true?
        i = 0
        while not keyboard.is_pressed('q'):
            try:
                if keyboard.is_pressed('c'):  # if key 'c' is pressed 
                    print('You Pressed A Key!')
                    i = i + 1
    
    
                

                #  Retrieve next received image
                #
                #  *** NOTES ***
                #  Capturing an image houses images on the camera buffer. Trying
                #  to capture an image that does not exist will hang the camera.
                #
                #  *** LATER ***
                #  Once an image from the buffer is saved and/or no longer
                #  needed, the image must be released in order to keep the
                #  buffer from filling up.
                    image_result = cam.GetNextImage(1000)

                #  Ensure image completion
                #
                #  *** NOTES ***
                #  Images can easily be checked for completion. This should be
                #  done whenever a complete image is expected or required.
                #  Further, check image status for a little more insight into
                #  why an image is incomplete.
                    if image_result.IsIncomplete():
                        print('Image incomplete with image status %d ...' % image_result.GetImageStatus())

                    else:

                    #  Print image information; height and width recorded in pixels
                    #
                    #  *** NOTES ***
                    #  Images have quite a bit of available metadata including
                    #  things such as CRC, image status, and offset values, to
                    #  name a few.
                        width = image_result.GetWidth()
                        height = image_result.GetHeight()
                        print('Grabbed Image %d, width = %d, height = %d' % (i, width, height))

                    #  Convert image to mono 8
                    #
                    #  *** NOTES ***
                    #  Images can be converted between pixel formats by using
                    #  the appropriate enumeration value. Unlike the original
                    #  image, the converted one does not need to be released as
                    #  it does not affect the camera buffer.
                    #
                    #  When converting images, color processing algorithm is an
                    #  optional parameter.
                    
                    ## This converts it to GreyScale
                    #image_converted = image_result.Convert(spin.PixelFormat_Mono8, spin.HQ_LINEAR)
                    ## This converts it to RGB
                        #image_converted = image_result.Convert(spin.PixelFormat_BGR8)
                        
                        
                        image_converted = image_result.Convert(spin.PixelFormat_BGR8)
                        rgb_array = image_converted.GetData()
                        rgb_array = rgb_array.reshape(height, width, 3)
                    
                            
                        ## process mediapipe on image
                        image_rgb = cv2.cvtColor(cv2.flip(rgb_array, 1), cv2.COLOR_BGR2RGB)
                            
                            
                        ## **** Resizing / Croping *****
                            
                        ## RESIZING the image since it would be 2048x2048 otherwise (kind of too big for the window)
                        #image_rgb = cv2.resize(image_rgb, (800, 800))
                        ## this is to display potential cropping region in the downscaled image
                        # scale = 800/2048   
                        # cv2.rectangle(image_rgb, (int(650*scale), int(580*scale)), (int(1450*scale), int(1380*scale)), (0, 255, 0), 3)
                                                        
                        ## CROPPPING the region of the lense (should be around 800 to fit with the setup so far...)
                        ## This is the cropping
                        ## These values are taken from the unity config
                        ## They might change... [y:y+h, x:x+h]
                        array_cropped = image_rgb[ROI_y:(ROI_y + ROI_height), ROI_x:(ROI_x + ROI_width)]
                        image_rgb = array_cropped.copy() # needed to get the correct data format for further processing
                          
                        image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)
                    
                    
                    
                    
                        ## Saving the image to a folder
                        # Create a unique filename
                        if calibPictureFilename:
                            filename = 'CameraFeed\%s-%d.jpg' % (calibPictureFilename, i)
                        else:
                            if device_serial_number:
                                filename = 'CameraFeed\Acquisition-%s-%d.jpg' % (device_serial_number, i)
                            else:  # if serial number is empty
                                filename = 'CameraFeed\Acquisition-%d.jpg' % i
                               
                        #  Save image
                        #
                        #  *** NOTES ***
                        #  The standard practice of the examples is to use device
                        #  serial numbers to keep images of one device from
                        #  overwriting those of another.
                        #image_converted.Save(filename)
                        cv2.imwrite(filename, image_rgb)
                        print('Image saved at %s' % filename)

                        #  Release image
                        #
                        #  *** NOTES ***
                        #  Images retrieved directly from the camera (i.e. non-converted
                        #  images) need to be released in order to keep from filling the
                        #  buffer.
                        image_result.Release()
                        print('')

                
                else:
                    ## when no capturing key is pressed the image still needs to be loaded, otherwise the images will pile up in the buffer
                    image_result = cam.GetNextImage(1000)
                    image_result.Release()
                
                
                
                
            except spin.SpinnakerException as ex:
                print('Error: %s' % ex)
                return False

        #  End acquisition
        #
        #  *** NOTES ***
        #  Ending acquisition appropriately helps ensure that devices clean up
        #  properly and do not need to be power-cycled to maintain integrity.
        cam.EndAcquisition()
    
    except spin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return result






def print_device_info(nodemap):
    """
    This function prints the device information of the camera from the transport
    layer; please see NodeMapInfo example for more in-depth comments on printing
    device information from the nodemap.

    :param nodemap: Transport layer device nodemap.
    :type nodemap: INodeMap
    :returns: True if successful, False otherwise.
    :rtype: bool
    """

    print('*** DEVICE INFORMATION ***\n')

    try:
        result = True
        node_device_information = spin.CCategoryPtr(nodemap.GetNode('DeviceInformation'))

        if spin.IsAvailable(node_device_information) and spin.IsReadable(node_device_information):
            features = node_device_information.GetFeatures()
            for feature in features:
                node_feature = spin.CValuePtr(feature)
                print('%s: %s' % (node_feature.GetName(),
                                  node_feature.ToString() if spin.IsReadable(node_feature) else 'Node not readable'))

        else:
            print('Device control information not available.')

    except spin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return result







def run_single_camera(cam):
    """
    This function acts as the body of the example; please see NodeMapInfo example
    for more in-depth comments on setting up cameras.

    :param cam: Camera to run on.
    :type cam: CameraPtr
    :return: True if successful, False otherwise.
    :rtype: bool
    """
    try:
        result = True

        # Retrieve TL device nodemap and print device information
        nodemap_tldevice = cam.GetTLDeviceNodeMap()

        result &= print_device_info(nodemap_tldevice)

        # Initialize camera
        cam.Init()

        # Retrieve GenICam nodemap
        nodemap = cam.GetNodeMap()

        # Acquire images
        result &= acquire_images(cam, nodemap, nodemap_tldevice)

        # Deinitialize camera
        cam.DeInit()

    except spin.SpinnakerException as ex:
        print('Error: %s' % ex)
        result = False

    return result










def main():
    """
    Example entry point; please see Enumeration example for more in-depth
    comments on preparing and cleaning up the system.

    :return: True if successful, False otherwise.
    :rtype: bool
    """

    # Since this application saves images in the current folder
    # we must ensure that we have permission to write to this folder.
    # If we do not have permission, fail right away.
    try:
        test_file = open('test.txt', 'w+')
    except IOError:
        print('Unable to write to current directory. Please check permissions.')
        input('Press Enter to exit...')
        return False

    test_file.close()
    os.remove(test_file.name)

    result = True

    # Retrieve singleton reference to system object
    system = spin.System.GetInstance()

    # Get current library version
    version = system.GetLibraryVersion()
    print('Library version: %d.%d.%d.%d' % (version.major, version.minor, version.type, version.build))

    # Retrieve list of cameras from the system
    cam_list = system.GetCameras()

    num_cameras = cam_list.GetSize()

    print('Number of cameras detected: %d' % num_cameras)

    # Finish if there are no cameras
    if num_cameras == 0:

        # Clear camera list before releasing system
        cam_list.Clear()

        # Release system instance
        system.ReleaseInstance()

        print('Not enough cameras!')
        input('Done! Press Enter to exit...')
        return False

    # Run example on each camera
    for i, cam in enumerate(cam_list):

        print('Running example for camera %d...' % i)

        result &= run_single_camera(cam)
        print('Camera %d example complete... \n' % i)

    # Release reference to camera
    # NOTE: Unlike the C++ examples, we cannot rely on pointer objects being automatically
    # cleaned up when going out of scope.
    # The usage of del is preferred to assigning the variable to None.
    del cam

    # Clear camera list before releasing system
    cam_list.Clear()

    # Release system instance
    system.ReleaseInstance()

    input('Done! Press Enter to exit...')
    return result

if __name__ == '__main__':
    if main():
        sys.exit(0)
    else:
        sys.exit(1)
# Out:
# Library version: 2.4.0.144
# Number of cameras detected: 1
# Running example for camera 0...
# *** DEVICE INFORMATION ***
#
# DeviceID: USB\VID_1E10&PID_3300&MI_00\6&284BB4E7&1&0000
# DeviceSerialNumber: 20413825
# DeviceVendorName: Point Grey Research
# DeviceModelName: Grasshopper3 GS3-U3-41C6NIR
# DeviceType: USB3Vision
# DeviceDisplayName: Point Grey Research Grasshopper3 GS3-U3-41C6NIR
# DeviceAccessStatus: OpenReadWrite
# DeviceVersion: FW:v2.23.3.02 FPGA:v2.02
# DeviceDriverVersion: PGRUSBCam.sys : 2.7.3.235
# DeviceUserID:
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_3300&MI_00\6&284BB4E7&1&0000
# DeviceLocation: 0000.0014.0000.020.000.000.000.000.000
# DeviceCurrentSpeed: SuperSpeed
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# GenICamXMLLocation: Device
# GenICamXMLPath:
# DeviceU3VProtocol: 1
# DevicePortId: 20
# *** IMAGE ACQUISITION ***
#
# Acquisition mode set to continuous...
# Acquiring images...
# Device serial number retrieved as 20413825...
# You Pressed A Key!
# Grabbed Image 1, width = 2048, height = 2048
# Image saved at CameraFeed\Test-1.jpg
#
# You Pressed A Key!
# Grabbed Image 2, width = 2048, height = 2048
# Image saved at CameraFeed\Test-2.jpg
#
# You Pressed A Key!
# Grabbed Image 3, width = 2048, height = 2048
# Image saved at CameraFeed\Test-3.jpg
#
# You Pressed A Key!
# Grabbed Image 4, width = 2048, height = 2048
# Image saved at CameraFeed\Test-4.jpg
#
# You Pressed A Key!
# Grabbed Image 5, width = 2048, height = 2048
# Image saved at CameraFeed\Test-5.jpg
#
# You Pressed A Key!
# Grabbed Image 6, width = 2048, height = 2048
# Image saved at CameraFeed\Test-6.jpg
#
# You Pressed A Key!
# Grabbed Image 7, width = 2048, height = 2048
# Image saved at CameraFeed\Test-7.jpg
#
# You Pressed A Key!
# Grabbed Image 8, width = 2048, height = 2048
# Image saved at CameraFeed\Test-8.jpg
#
# You Pressed A Key!
# Grabbed Image 9, width = 2048, height = 2048
# Image saved at CameraFeed\Test-9.jpg
#
# You Pressed A Key!
# Grabbed Image 10, width = 2048, height = 2048
# Image saved at CameraFeed\Test-10.jpg
#
# You Pressed A Key!
# Grabbed Image 11, width = 2048, height = 2048
# Image saved at CameraFeed\Test-11.jpg
#
# You Pressed A Key!
# Grabbed Image 12, width = 2048, height = 2048
# Image saved at CameraFeed\Test-12.jpg
#
# You Pressed A Key!
# Grabbed Image 13, width = 2048, height = 2048
# Image saved at CameraFeed\Test-13.jpg
#
# You Pressed A Key!
# Grabbed Image 14, width = 2048, height = 2048
# Image saved at CameraFeed\Test-14.jpg
#
# You Pressed A Key!
# Grabbed Image 15, width = 2048, height = 2048
# Image saved at CameraFeed\Test-15.jpg
#
# You Pressed A Key!
# Grabbed Image 16, width = 2048, height = 2048
# Image saved at CameraFeed\Test-16.jpg
#
# You Pressed A Key!
# Grabbed Image 17, width = 2048, height = 2048
# Image saved at CameraFeed\Test-17.jpg
#
# You Pressed A Key!
# Grabbed Image 18, width = 2048, height = 2048
# Image saved at CameraFeed\Test-18.jpg
#
# You Pressed A Key!
# Grabbed Image 19, width = 2048, height = 2048
# Image saved at CameraFeed\Test-19.jpg
#
# You Pressed A Key!
# Grabbed Image 20, width = 2048, height = 2048
# Image saved at CameraFeed\Test-20.jpg
#
# You Pressed A Key!
# Grabbed Image 21, width = 2048, height = 2048
# Image saved at CameraFeed\Test-21.jpg
#
# You Pressed A Key!
# Grabbed Image 22, width = 2048, height = 2048
# Image saved at CameraFeed\Test-22.jpg
#
# You Pressed A Key!
# Grabbed Image 23, width = 2048, height = 2048
# Image saved at CameraFeed\Test-23.jpg
#
# You Pressed A Key!
# Grabbed Image 24, width = 2048, height = 2048
# Image saved at CameraFeed\Test-24.jpg
#
# You Pressed A Key!
# Grabbed Image 25, width = 2048, height = 2048
# Image saved at CameraFeed\Test-25.jpg
#
# You Pressed A Key!
# Grabbed Image 26, width = 2048, height = 2048
# Image saved at CameraFeed\Test-26.jpg
#
# You Pressed A Key!
# Grabbed Image 27, width = 2048, height = 2048
# Image saved at CameraFeed\Test-27.jpg
#
# You Pressed A Key!
# Grabbed Image 28, width = 2048, height = 2048
# Image saved at CameraFeed\Test-28.jpg
#
# You Pressed A Key!
# Grabbed Image 29, width = 2048, height = 2048
# Image saved at CameraFeed\Test-29.jpg
#
# You Pressed A Key!
# Grabbed Image 30, width = 2048, height = 2048
# Image saved at CameraFeed\Test-30.jpg
#
# You Pressed A Key!
# Grabbed Image 31, width = 2048, height = 2048
# Image saved at CameraFeed\Test-31.jpg
#
# You Pressed A Key!
# Grabbed Image 32, width = 2048, height = 2048
# Image saved at CameraFeed\Test-32.jpg
#
# You Pressed A Key!
# Grabbed Image 33, width = 2048, height = 2048
# Image saved at CameraFeed\Test-33.jpg
#
# You Pressed A Key!
# Grabbed Image 34, width = 2048, height = 2048
# Image saved at CameraFeed\Test-34.jpg
#
# You Pressed A Key!
# Grabbed Image 35, width = 2048, height = 2048
# Image saved at CameraFeed\Test-35.jpg
#
# You Pressed A Key!
# Grabbed Image 36, width = 2048, height = 2048
# Image saved at CameraFeed\Test-36.jpg
#
# You Pressed A Key!
# Grabbed Image 37, width = 2048, height = 2048
# Image saved at CameraFeed\Test-37.jpg
#
# You Pressed A Key!
# Grabbed Image 38, width = 2048, height = 2048
# Image saved at CameraFeed\Test-38.jpg
#
# You Pressed A Key!
# Grabbed Image 39, width = 2048, height = 2048
# Image saved at CameraFeed\Test-39.jpg
#
# You Pressed A Key!
# Grabbed Image 40, width = 2048, height = 2048
# Image saved at CameraFeed\Test-40.jpg
#
# You Pressed A Key!
# Grabbed Image 41, width = 2048, height = 2048
# Image saved at CameraFeed\Test-41.jpg
#
# You Pressed A Key!
# Grabbed Image 42, width = 2048, height = 2048
# Image saved at CameraFeed\Test-42.jpg
#
# You Pressed A Key!
# Grabbed Image 43, width = 2048, height = 2048
# Image saved at CameraFeed\Test-43.jpg
#
# You Pressed A Key!
# Grabbed Image 44, width = 2048, height = 2048
# Image saved at CameraFeed\Test-44.jpg
#
# You Pressed A Key!
# Grabbed Image 45, width = 2048, height = 2048
# Image saved at CameraFeed\Test-45.jpg
#
# You Pressed A Key!
# Grabbed Image 46, width = 2048, height = 2048
# Image saved at CameraFeed\Test-46.jpg
#
# You Pressed A Key!
# Grabbed Image 47, width = 2048, height = 2048
# Image saved at CameraFeed\Test-47.jpg
#
# You Pressed A Key!
# Grabbed Image 48, width = 2048, height = 2048
# Image saved at CameraFeed\Test-48.jpg
#
# You Pressed A Key!
# Grabbed Image 49, width = 2048, height = 2048
# Image saved at CameraFeed\Test-49.jpg
#
# You Pressed A Key!
# Grabbed Image 50, width = 2048, height = 2048
# Image saved at CameraFeed\Test-50.jpg
#
# You Pressed A Key!
# Grabbed Image 51, width = 2048, height = 2048
# Image saved at CameraFeed\Test-51.jpg
#
# You Pressed A Key!
# Grabbed Image 52, width = 2048, height = 2048
# Image saved at CameraFeed\Test-52.jpg
#
# You Pressed A Key!
# Grabbed Image 53, width = 2048, height = 2048
# Image saved at CameraFeed\Test-53.jpg
#
# You Pressed A Key!
# Grabbed Image 54, width = 2048, height = 2048
# Image saved at CameraFeed\Test-54.jpg
#
# You Pressed A Key!
# Grabbed Image 55, width = 2048, height = 2048
# Image saved at CameraFeed\Test-55.jpg
#
# You Pressed A Key!
# Grabbed Image 56, width = 2048, height = 2048
# Image saved at CameraFeed\Test-56.jpg
#
# You Pressed A Key!
# Grabbed Image 57, width = 2048, height = 2048
# Image saved at CameraFeed\Test-57.jpg
#
# You Pressed A Key!
# Grabbed Image 58, width = 2048, height = 2048
# Image saved at CameraFeed\Test-58.jpg
#
# You Pressed A Key!
# Grabbed Image 59, width = 2048, height = 2048
# Image saved at CameraFeed\Test-59.jpg
#
# You Pressed A Key!
# Grabbed Image 60, width = 2048, height = 2048
# Image saved at CameraFeed\Test-60.jpg
#
# You Pressed A Key!
# Grabbed Image 61, width = 2048, height = 2048
# Image saved at CameraFeed\Test-61.jpg
#
# You Pressed A Key!
# Grabbed Image 62, width = 2048, height = 2048
# Image saved at CameraFeed\Test-62.jpg
#
# You Pressed A Key!
# Grabbed Image 63, width = 2048, height = 2048
# Image saved at CameraFeed\Test-63.jpg
#
# You Pressed A Key!
# Grabbed Image 64, width = 2048, height = 2048
# Image saved at CameraFeed\Test-64.jpg
#
# You Pressed A Key!
# Grabbed Image 65, width = 2048, height = 2048
# Image saved at CameraFeed\Test-65.jpg
#
# You Pressed A Key!
# Grabbed Image 66, width = 2048, height = 2048
# Image saved at CameraFeed\Test-66.jpg
#
# You Pressed A Key!
# Grabbed Image 67, width = 2048, height = 2048
# Image saved at CameraFeed\Test-67.jpg
#
# You Pressed A Key!
# Grabbed Image 68, width = 2048, height = 2048
# Image saved at CameraFeed\Test-68.jpg
#
# You Pressed A Key!
# Grabbed Image 69, width = 2048, height = 2048
# Image saved at CameraFeed\Test-69.jpg
#
# You Pressed A Key!
# Grabbed Image 70, width = 2048, height = 2048
# Image saved at CameraFeed\Test-70.jpg
# You Pressed A Key!
# Grabbed Image 71, width = 2048, height = 2048
# Image saved at CameraFeed\Test-71.jpg
#
# You Pressed A Key!
# Grabbed Image 72, width = 2048, height = 2048
# Image saved at CameraFeed\Test-72.jpg
#
# You Pressed A Key!
# Grabbed Image 73, width = 2048, height = 2048
# Image saved at CameraFeed\Test-73.jpg
#
# You Pressed A Key!
# Grabbed Image 74, width = 2048, height = 2048
# Image saved at CameraFeed\Test-74.jpg
#
# You Pressed A Key!
# Grabbed Image 75, width = 2048, height = 2048
# Image saved at CameraFeed\Test-75.jpg
#
# You Pressed A Key!
# Grabbed Image 76, width = 2048, height = 2048
# Image saved at CameraFeed\Test-76.jpg
#
# You Pressed A Key!
# Grabbed Image 77, width = 2048, height = 2048
# Image saved at CameraFeed\Test-77.jpg
#
# You Pressed A Key!
# Grabbed Image 78, width = 2048, height = 2048
# Image saved at CameraFeed\Test-78.jpg
#
# You Pressed A Key!
# Grabbed Image 79, width = 2048, height = 2048
# Image saved at CameraFeed\Test-79.jpg
#
# You Pressed A Key!
# Grabbed Image 80, width = 2048, height = 2048
# Image saved at CameraFeed\Test-80.jpg
#
# You Pressed A Key!
# Grabbed Image 81, width = 2048, height = 2048
# Image saved at CameraFeed\Test-81.jpg
#
# You Pressed A Key!
# Grabbed Image 82, width = 2048, height = 2048
# Image saved at CameraFeed\Test-82.jpg
#
# You Pressed A Key!
# Grabbed Image 83, width = 2048, height = 2048
# Image saved at CameraFeed\Test-83.jpg
#
# You Pressed A Key!
# Grabbed Image 84, width = 2048, height = 2048
# Image saved at CameraFeed\Test-84.jpg
#
# You Pressed A Key!
# Grabbed Image 85, width = 2048, height = 2048
# Image saved at CameraFeed\Test-85.jpg
#
# You Pressed A Key!
# Grabbed Image 86, width = 2048, height = 2048
# Image saved at CameraFeed\Test-86.jpg
#
# You Pressed A Key!
# Grabbed Image 87, width = 2048, height = 2048
# Image saved at CameraFeed\Test-87.jpg
#
# You Pressed A Key!
# Grabbed Image 88, width = 2048, height = 2048
# Image saved at CameraFeed\Test-88.jpg
#
# You Pressed A Key!
# Grabbed Image 89, width = 2048, height = 2048
# Image saved at CameraFeed\Test-89.jpg
#
# You Pressed A Key!
# Grabbed Image 90, width = 2048, height = 2048
# Image saved at CameraFeed\Test-90.jpg
#
# You Pressed A Key!
# Grabbed Image 91, width = 2048, height = 2048
# Image saved at CameraFeed\Test-91.jpg
#
# You Pressed A Key!
# Grabbed Image 92, width = 2048, height = 2048
# Image saved at CameraFeed\Test-92.jpg
#
# You Pressed A Key!
# Grabbed Image 93, width = 2048, height = 2048
# Image saved at CameraFeed\Test-93.jpg
#
# You Pressed A Key!
# Grabbed Image 94, width = 2048, height = 2048
# Image saved at CameraFeed\Test-94.jpg
#
# You Pressed A Key!
# Grabbed Image 95, width = 2048, height = 2048
# Image saved at CameraFeed\Test-95.jpg
#
# You Pressed A Key!
# Grabbed Image 96, width = 2048, height = 2048
# Image saved at CameraFeed\Test-96.jpg
#
# You Pressed A Key!
# Grabbed Image 97, width = 2048, height = 2048
# Image saved at CameraFeed\Test-97.jpg
#
# You Pressed A Key!
# Grabbed Image 98, width = 2048, height = 2048
# Image saved at CameraFeed\Test-98.jpg
#
# You Pressed A Key!
# Grabbed Image 99, width = 2048, height = 2048
# Image saved at CameraFeed\Test-99.jpg
#
# You Pressed A Key!
# Grabbed Image 100, width = 2048, height = 2048
# Image saved at CameraFeed\Test-100.jpg
#
# You Pressed A Key!
# Grabbed Image 101, width = 2048, height = 2048
# Image saved at CameraFeed\Test-101.jpg
#
# You Pressed A Key!
# Grabbed Image 102, width = 2048, height = 2048
# Image saved at CameraFeed\Test-102.jpg
#
# You Pressed A Key!
# Grabbed Image 103, width = 2048, height = 2048
# Image saved at CameraFeed\Test-103.jpg
#
# You Pressed A Key!
# Grabbed Image 104, width = 2048, height = 2048
# Image saved at CameraFeed\Test-104.jpg
#
# You Pressed A Key!
# Grabbed Image 105, width = 2048, height = 2048
# Image saved at CameraFeed\Test-105.jpg
#
# You Pressed A Key!
# Grabbed Image 106, width = 2048, height = 2048
# Image saved at CameraFeed\Test-106.jpg
#
# You Pressed A Key!
# Grabbed Image 107, width = 2048, height = 2048
# Image saved at CameraFeed\Test-107.jpg
#
# You Pressed A Key!
# Grabbed Image 108, width = 2048, height = 2048
# Image saved at CameraFeed\Test-108.jpg
#
# You Pressed A Key!
# Grabbed Image 109, width = 2048, height = 2048
# Image saved at CameraFeed\Test-109.jpg
#
# You Pressed A Key!
# Grabbed Image 110, width = 2048, height = 2048
# Image saved at CameraFeed\Test-110.jpg
#
# You Pressed A Key!
# Grabbed Image 111, width = 2048, height = 2048
# Image saved at CameraFeed\Test-111.jpg
#
# You Pressed A Key!
# Grabbed Image 112, width = 2048, height = 2048
# Image saved at CameraFeed\Test-112.jpg
#
# You Pressed A Key!
# Grabbed Image 113, width = 2048, height = 2048
# Image saved at CameraFeed\Test-113.jpg
#
# You Pressed A Key!
# Grabbed Image 114, width = 2048, height = 2048
# Image saved at CameraFeed\Test-114.jpg
#
# You Pressed A Key!
# Grabbed Image 115, width = 2048, height = 2048
# Image saved at CameraFeed\Test-115.jpg
#
# You Pressed A Key!
# Grabbed Image 116, width = 2048, height = 2048
# Image saved at CameraFeed\Test-116.jpg
#
# You Pressed A Key!
# Grabbed Image 117, width = 2048, height = 2048
# Image saved at CameraFeed\Test-117.jpg
#
# You Pressed A Key!
# Grabbed Image 118, width = 2048, height = 2048
# Image saved at CameraFeed\Test-118.jpg
#
# You Pressed A Key!
# Grabbed Image 119, width = 2048, height = 2048
# Image saved at CameraFeed\Test-119.jpg
#
# You Pressed A Key!
# Grabbed Image 120, width = 2048, height = 2048
# Image saved at CameraFeed\Test-120.jpg
#
# You Pressed A Key!
# Grabbed Image 121, width = 2048, height = 2048
# Image saved at CameraFeed\Test-121.jpg
#
# You Pressed A Key!
# Grabbed Image 122, width = 2048, height = 2048
# Image saved at CameraFeed\Test-122.jpg
#
# You Pressed A Key!
# Grabbed Image 123, width = 2048, height = 2048
# Image saved at CameraFeed\Test-123.jpg
#
# You Pressed A Key!
# Grabbed Image 124, width = 2048, height = 2048
# Image saved at CameraFeed\Test-124.jpg
#
# You Pressed A Key!
# Grabbed Image 125, width = 2048, height = 2048
# Image saved at CameraFeed\Test-125.jpg
#
# You Pressed A Key!
# Grabbed Image 126, width = 2048, height = 2048
# Image saved at CameraFeed\Test-126.jpg
#
# You Pressed A Key!
# Grabbed Image 127, width = 2048, height = 2048
# Image saved at CameraFeed\Test-127.jpg
#
# You Pressed A Key!
# Grabbed Image 128, width = 2048, height = 2048
# Image saved at CameraFeed\Test-128.jpg
#
# You Pressed A Key!
# Grabbed Image 129, width = 2048, height = 2048
# Image saved at CameraFeed\Test-129.jpg
#
# You Pressed A Key!
# Grabbed Image 130, width = 2048, height = 2048
# Image saved at CameraFeed\Test-130.jpg
#
# You Pressed A Key!
# Grabbed Image 131, width = 2048, height = 2048
# Image saved at CameraFeed\Test-131.jpg
#
# You Pressed A Key!
# Grabbed Image 132, width = 2048, height = 2048
# Image saved at CameraFeed\Test-132.jpg
#
# You Pressed A Key!
# Grabbed Image 133, width = 2048, height = 2048
# Image saved at CameraFeed\Test-133.jpg
#
# You Pressed A Key!
# Grabbed Image 134, width = 2048, height = 2048
# Image saved at CameraFeed\Test-134.jpg
#
# You Pressed A Key!
# Grabbed Image 135, width = 2048, height = 2048
# Image saved at CameraFeed\Test-135.jpg
#
# You Pressed A Key!
# Grabbed Image 136, width = 2048, height = 2048
# Image saved at CameraFeed\Test-136.jpg
#
# You Pressed A Key!
# Grabbed Image 137, width = 2048, height = 2048
# Image saved at CameraFeed\Test-137.jpg
#
# You Pressed A Key!
# Grabbed Image 138, width = 2048, height = 2048
# Image saved at CameraFeed\Test-138.jpg
#
# You Pressed A Key!
# Grabbed Image 139, width = 2048, height = 2048
# Image saved at CameraFeed\Test-139.jpg
#
# You Pressed A Key!
# Grabbed Image 140, width = 2048, height = 2048
# Image saved at CameraFeed\Test-140.jpg
#
# You Pressed A Key!
# Grabbed Image 141, width = 2048, height = 2048
# Image saved at CameraFeed\Test-141.jpg
#
# You Pressed A Key!
# Grabbed Image 142, width = 2048, height = 2048
# Image saved at CameraFeed\Test-142.jpg
#
# You Pressed A Key!
# Grabbed Image 143, width = 2048, height = 2048
# Image saved at CameraFeed\Test-143.jpg
#
# You Pressed A Key!
# Grabbed Image 144, width = 2048, height = 2048
# Image saved at CameraFeed\Test-144.jpg
#
# You Pressed A Key!
# Grabbed Image 145, width = 2048, height = 2048
# Image saved at CameraFeed\Test-145.jpg
#
# You Pressed A Key!
# Grabbed Image 146, width = 2048, height = 2048
# Image saved at CameraFeed\Test-146.jpg
#
# You Pressed A Key!
# Grabbed Image 147, width = 2048, height = 2048
# Image saved at CameraFeed\Test-147.jpg
#
# You Pressed A Key!
# Grabbed Image 148, width = 2048, height = 2048
# Image saved at CameraFeed\Test-148.jpg
#
# You Pressed A Key!
# Grabbed Image 149, width = 2048, height = 2048
# Image saved at CameraFeed\Test-149.jpg
# You Pressed A Key!
# Grabbed Image 150, width = 2048, height = 2048
# Image saved at CameraFeed\Test-150.jpg
#
# You Pressed A Key!
# Grabbed Image 151, width = 2048, height = 2048
# Image saved at CameraFeed\Test-151.jpg
#
# You Pressed A Key!
# Grabbed Image 152, width = 2048, height = 2048
# Image saved at CameraFeed\Test-152.jpg
#
# You Pressed A Key!
# Grabbed Image 153, width = 2048, height = 2048
# Image saved at CameraFeed\Test-153.jpg
#
# You Pressed A Key!
# Grabbed Image 154, width = 2048, height = 2048
# Image saved at CameraFeed\Test-154.jpg
#
# You Pressed A Key!
# Grabbed Image 155, width = 2048, height = 2048
# Image saved at CameraFeed\Test-155.jpg
#
# You Pressed A Key!
# Grabbed Image 156, width = 2048, height = 2048
# Image saved at CameraFeed\Test-156.jpg
#
# You Pressed A Key!
# Grabbed Image 157, width = 2048, height = 2048
# Image saved at CameraFeed\Test-157.jpg
#
# You Pressed A Key!
# Grabbed Image 158, width = 2048, height = 2048
# Image saved at CameraFeed\Test-158.jpg
#
# You Pressed A Key!
# Grabbed Image 159, width = 2048, height = 2048
# Image saved at CameraFeed\Test-159.jpg
#
# You Pressed A Key!
# Grabbed Image 160, width = 2048, height = 2048
# Image saved at CameraFeed\Test-160.jpg
#
# You Pressed A Key!
# Grabbed Image 161, width = 2048, height = 2048
# Image saved at CameraFeed\Test-161.jpg
#
# You Pressed A Key!
# Grabbed Image 162, width = 2048, height = 2048
# Image saved at CameraFeed\Test-162.jpg
#
# You Pressed A Key!
# Grabbed Image 163, width = 2048, height = 2048
# Image saved at CameraFeed\Test-163.jpg
#
# You Pressed A Key!
# Grabbed Image 164, width = 2048, height = 2048
# Image saved at CameraFeed\Test-164.jpg
#
# You Pressed A Key!
# Grabbed Image 165, width = 2048, height = 2048
# Image saved at CameraFeed\Test-165.jpg
#
# You Pressed A Key!
# Grabbed Image 166, width = 2048, height = 2048
# Image saved at CameraFeed\Test-166.jpg
#
# You Pressed A Key!
# Grabbed Image 167, width = 2048, height = 2048
# Image saved at CameraFeed\Test-167.jpg
#
# You Pressed A Key!
# Grabbed Image 168, width = 2048, height = 2048
# Image saved at CameraFeed\Test-168.jpg
#
# You Pressed A Key!
# Grabbed Image 169, width = 2048, height = 2048
# Image saved at CameraFeed\Test-169.jpg
#
# You Pressed A Key!
# Grabbed Image 170, width = 2048, height = 2048
# Image saved at CameraFeed\Test-170.jpg
#
# You Pressed A Key!
# Grabbed Image 171, width = 2048, height = 2048
# Image saved at CameraFeed\Test-171.jpg
#
# You Pressed A Key!
# Grabbed Image 172, width = 2048, height = 2048
# Image saved at CameraFeed\Test-172.jpg
#
# You Pressed A Key!
# Grabbed Image 173, width = 2048, height = 2048
# Image saved at CameraFeed\Test-173.jpg
#
# You Pressed A Key!
# Grabbed Image 174, width = 2048, height = 2048
# Image saved at CameraFeed\Test-174.jpg
#
# You Pressed A Key!
# Grabbed Image 175, width = 2048, height = 2048
# Image saved at CameraFeed\Test-175.jpg
#
# You Pressed A Key!
# Grabbed Image 176, width = 2048, height = 2048
# Image saved at CameraFeed\Test-176.jpg
#
# Camera 0 example complete...
#
# Done! Press Enter to exit...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
## OLD: Undistort for normal lense but we need to use fisheye calibration


import numpy as np
import cv2 as cv
import glob
import keyboard
import time


## parameters

calibPictureFilename = "TestFeed\Test"





def main():
    # termination criteria
    criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 0.001)

    # prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
    objp = np.zeros((6*9,3), np.float32)
    objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

    # Arrays to store object points and image points from all the images.
    objpoints = [] # 3d point in real world space
    imgpoints = [] # 2d points in image plane.

    images = glob.glob('TestFeed/*.jpg')

    i=0

    for fname in images:
    
        img = cv.imread(fname)
        print('Search image in %s' %fname)
    
        gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    
        # Find the chess board corners
        ret, corners = cv.findChessboardCorners(gray, (9,6), None)
    
        # If found, add object points, image points (after refining them)
        if ret == True:
            objpoints.append(objp)
            corners2 = cv.cornerSubPix(gray,corners, (11,11), (-1,-1), criteria)
            imgpoints.append(corners)
        
            # Draw and display the corners
            cv.drawChessboardCorners(img, (9,6), corners2, ret)
            cv.imshow('img', img)
            cv.imwrite('%s-%d.jpg' %(calibPictureFilename, i), img)
            print('Image saved at %s' % fname)
            cv.waitKey(500)
        
        
            ## camera calibration
            ret, mtx, dist, rvecs, tvecs = cv.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
            
            print(fname)
            img = cv.imread(fname)
            print(img)
            h,  w = img.shape[:2]
            newcameramtx, roi = cv.getOptimalNewCameraMatrix(mtx, dist, (w,h), 1, (w,h))
            
            # undistort
            dst = cv.undistort(img, mtx, dist, None, newcameramtx)
            # crop the image
            x, y, w, h = roi
            dst = dst[y:y+h, x:x+w]
            cv.imwrite('TestFeed\calibresult_%d.png' %i , dst)
            
            ## this stores the objectpoints in a textfile for now bccccccccccccccccqut the format does not work yet
            file = open("TestFeed/Test.txt", "a")
            file.write("objectPoints, " + str(objpoints))
            
            # NEXT: undistort picture
            
        
            
            i = i + 1
        
        else:
            print('No chessboard found')
 


    cv.destroyAllWindows()
    

    
    

main()
# Out:
# Search image in TestFeed\Test-10.jpg
# Image saved at TestFeed\Test-10.jpg
# TestFeed\Test-10.jpg
# [[[33 24 21]
#   [34 25 22]
#   [36 24 24]
#   ...
#   [36 24 22]
#   [38 25 23]
#   [39 26 24]]
#
#  [[34 25 22]
#   [34 25 22]
#   [36 24 24]
#   ...
#   [36 24 22]
#   [38 25 23]
#   [38 25 23]]
#
#  [[34 25 22]
#   [34 25 22]
#   [36 24 24]
#   ...
#   [36 24 22]
#   [37 25 23]
#   [37 25 23]]
#
#  ...
#
#  [[34 25 22]
#   [34 25 22]
#   [33 24 21]
#   ...
#   [34 24 24]
#   [37 25 23]
#   [38 26 24]]
#
#  [[32 23 20]
#   [33 24 21]
#   [33 24 21]
#   ...
#   [35 23 21]
#   [37 24 22]
#   [37 24 22]]
#
#  [[31 22 19]
#   [33 24 21]
#   [34 25 22]
#   ...
#   [35 23 21]
#   [35 22 20]
#   [34 21 19]]]
# Search image in TestFeed\Test-11.jpg
# Image saved at TestFeed\Test-11.jpg
# TestFeed\Test-11.jpg
# [[[38 25 23]
#   [38 25 23]
#   [37 25 23]
#   ...
#   [36 23 21]
#   [38 24 25]
#   [41 27 28]]
#
#  [[38 25 23]
#   [37 24 22]
#   [36 24 22]
#   ...
#   [36 23 21]
#   [38 24 25]
#   [39 25 26]]
#
#  [[37 24 22]
#   [37 24 22]
#   [35 23 21]
#   ...
#   [36 24 24]
#   [36 24 24]
#   [36 24 24]]
#
#  ...
#
#  [[36 24 22]
#   [33 24 21]
#   [36 24 22]
#   ...
#   [33 23 23]
#   [34 24 24]
#   [35 25 25]]
#
#  [[35 22 20]
#   [34 22 20]
#   [33 24 21]
#   ...
#   [33 23 23]
#   [33 23 23]
#   [34 24 24]]
#
#  [[34 21 19]
#   [34 22 20]
#   [32 23 20]
#   ...
#   [33 23 23]
#   [33 23 23]
#   [33 23 23]]]
# Search image in TestFeed\Test-12.jpg
# Image saved at TestFeed\Test-12.jpg
# TestFeed\Test-12.jpg
# [[[34 24 24]
#   [34 24 24]
#   [33 23 23]
#   ...
#   [36 24 22]
#   [36 24 22]
#   [36 24 22]]
#
#  [[34 24 24]
#   [34 24 24]
#   [33 23 23]
#   ...
#   [35 23 21]
#   [36 24 22]
#   [37 25 23]]
#
#  [[35 25 25]
#   [35 25 25]
#   [34 24 24]
#   ...
#   [34 22 20]
#   [35 23 21]
#   [37 25 23]]
#
#  ...
#
#  [[35 25 25]
#   [35 25 25]
#   [35 25 25]
#   ...
#   [33 23 23]
#   [34 23 25]
#   [36 25 27]]
#
#  [[34 22 22]
#   [34 24 24]
#   [32 24 24]
#   ...
#   [34 21 23]
#   [35 22 24]
#   [36 23 25]]
#
#  [[33 21 21]
#   [33 23 23]
#   [32 24 24]
#   ...
#   [34 21 23]
#   [34 21 23]
#   [35 22 24]]]
# Search image in TestFeed\Test-13.jpg
# Image saved at TestFeed\Test-13.jpg
# TestFeed\Test-13.jpg
# [[[36 24 22]
#   [36 24 22]
#   [30 20 20]
#   ...
#   [39 24 22]
#   [38 23 21]
#   [38 23 21]]
#
#  [[37 25 23]
#   [38 26 24]
#   [32 22 22]
#   ...
#   [39 24 22]
#   [40 25 23]
#   [40 25 23]]
#
#  [[36 24 22]
#   [36 24 22]
#   [32 23 20]
#   ...
#   [36 22 23]
#   [40 24 25]
#   [41 25 26]]
#
#  ...
#
#  [[34 24 24]
#   [33 23 23]
#   [35 25 25]
#   ...
#   [35 23 21]
#   [37 25 23]
#   [38 26 24]]
#
#  [[31 23 23]
#   [30 22 22]
#   [32 24 24]
#   ...
#   [35 23 21]
#   [37 24 22]
#   [37 24 22]]
#
#  [[31 23 23]
#   [30 22 22]
#   [32 24 24]
#   ...
#   [34 22 20]
#   [36 23 21]
#   [36 23 21]]]
# Search image in TestFeed\Test-14.jpg
# No chessboard found
# Search image in TestFeed\Test-15.jpg
# No chessboard found
# Search image in TestFeed\Test-19.jpg
# No chessboard found
# Search image in TestFeed\Test-20.jpg
# No chessboard found
# Search image in TestFeed\Test-21.jpg
# No chessboard found
# Search image in TestFeed\Test-25.jpg
# No chessboard found
# Search image in TestFeed\Test-26.jpg
# No chessboard found
# Search image in TestFeed\Test-27.jpg
# No chessboard found
# Search image in TestFeed\Test-28.jpg
# No chessboard found
# Search image in TestFeed\Test-29.jpg
# No chessboard found
# Search image in TestFeed\Test-30.jpg
# No chessboard found
# Search image in TestFeed\Test-31.jpg
# No chessboard found
# Search image in TestFeed\Test-32.jpg
# No chessboard found
# Search image in TestFeed\Test-38.jpg
# No chessboard found
# Search image in TestFeed\Test-39.jpg
# No chessboard found
# Search image in TestFeed\Test-4.jpg
# No chessboard found
# Search image in TestFeed\Test-40.jpg
# No chessboard found
# Search image in TestFeed\Test-5.jpg
# No chessboard found
# Search image in TestFeed\Test-8.jpg
# Image saved at TestFeed\Test-8.jpg
# TestFeed\Test-8.jpg
# [[[32 24 24]
#   [33 25 25]
#   [28 23 22]
#   ...
#   [37 25 23]
#   [38 26 24]
#   [38 26 24]]
#
#  [[34 24 24]
#   [32 24 24]
#   [30 22 22]
#   ...
#   [38 26 24]
#   [38 26 24]
#   [38 26 24]]
#
#  [[38 26 26]
#   [36 26 26]
#   [34 24 24]
#   ...
#   [38 26 24]
#   [37 25 23]
#   [37 25 23]]
#
#  ...
#
#  [[29 24 23]
#   [31 26 25]
#   [33 25 25]
#   ...
#   [35 25 25]
#   [37 27 27]
#   [38 28 28]]
#
#  [[27 23 22]
#   [29 24 23]
#   [32 24 24]
#   ...
#   [33 23 23]
#   [33 23 23]
#   [33 23 23]]
#
#  [[27 23 22]
#   [28 24 23]
#   [31 23 23]
#   ...
#   [33 23 23]
#   [32 22 22]
#   [31 21 21]]]
# Search image in TestFeed\Test-9.jpg
# No chessboard found

# %%
## fisheye camera calibration
## use this to get the parameters and copy them to the undistortion function

import cv2
import numpy as np
import os
import glob

CHECKERBOARD = (5,7)

subpix_criteria = (cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER, 30, 0.1)
calibration_flags = cv2.fisheye.CALIB_RECOMPUTE_EXTRINSIC+cv2.fisheye.CALIB_CHECK_COND+cv2.fisheye.CALIB_FIX_SKEW

objp = np.zeros((1, CHECKERBOARD[0]*CHECKERBOARD[1], 3), np.float32)
objp[0,:,:2] = np.mgrid[0:CHECKERBOARD[0], 0:CHECKERBOARD[1]].T.reshape(-1, 2)

_img_shape = None

objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.

images = glob.glob('CameraFeed\*.jpg')

for fname in images:
    print("Processing image " + str(fname))
    img = cv2.imread(fname)
    if _img_shape == None:
        _img_shape = img.shape[:2]
    else:
        assert _img_shape == img.shape[:2], "All images must share the same size."
        

    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # Find the chess board corners
    ret, corners = cv2.findChessboardCorners(gray, CHECKERBOARD, cv2.CALIB_CB_ADAPTIVE_THRESH+cv2.CALIB_CB_FAST_CHECK+cv2.CALIB_CB_NORMALIZE_IMAGE)
    # If found, add object points, image points (after refining them)
    if ret == True:
        objpoints.append(objp)
        cv2.cornerSubPix(gray,corners,(3,3),(-1,-1),subpix_criteria)
        imgpoints.append(corners)
        print("Valid image: " + str(fname))
        
N_OK = len(objpoints)
K = np.zeros((3, 3))
D = np.zeros((4, 1))
rvecs = [np.zeros((1, 1, 3), dtype=np.float64) for i in range(N_OK)]
tvecs = [np.zeros((1, 1, 3), dtype=np.float64) for i in range(N_OK)]
rms, _, _, _, _ = \
    cv2.fisheye.calibrate(
        objpoints,
        imgpoints,
        gray.shape[::-1],
        K,
        D,
        rvecs,
        tvecs,
        calibration_flags,
        (cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER, 30, 1e-6)
    )

print("Found " + str(N_OK) + " valid images for calibration")
print("DIM=" + str(_img_shape[::-1]))
print("K=np.array(" + str(K.tolist()) + ")")
print("D=np.array(" + str(D.tolist()) + ")")
# Out:
# Processing image CameraFeed\Test-10.jpg
# Valid image: CameraFeed\Test-10.jpg
# Processing image CameraFeed\Test-100.jpg
# Valid image: CameraFeed\Test-100.jpg
# Processing image CameraFeed\Test-101.jpg
# Valid image: CameraFeed\Test-101.jpg
# Processing image CameraFeed\Test-102.jpg
# Valid image: CameraFeed\Test-102.jpg
# Processing image CameraFeed\Test-103.jpg
# Valid image: CameraFeed\Test-103.jpg
# Processing image CameraFeed\Test-104.jpg
# Valid image: CameraFeed\Test-104.jpg
# Processing image CameraFeed\Test-105.jpg
# Valid image: CameraFeed\Test-105.jpg
# Processing image CameraFeed\Test-106.jpg
# Valid image: CameraFeed\Test-106.jpg
# Processing image CameraFeed\Test-107.jpg
# Valid image: CameraFeed\Test-107.jpg
# Processing image CameraFeed\Test-108.jpg
# Valid image: CameraFeed\Test-108.jpg
# Processing image CameraFeed\Test-109.jpg
# Processing image CameraFeed\Test-112.jpg
# Valid image: CameraFeed\Test-112.jpg
# Processing image CameraFeed\Test-113.jpg
# Valid image: CameraFeed\Test-113.jpg
# Processing image CameraFeed\Test-114.jpg
# Valid image: CameraFeed\Test-114.jpg
# Processing image CameraFeed\Test-115.jpg
# Valid image: CameraFeed\Test-115.jpg
# Processing image CameraFeed\Test-116.jpg
# Valid image: CameraFeed\Test-116.jpg
# Processing image CameraFeed\Test-117.jpg
# Valid image: CameraFeed\Test-117.jpg
# Processing image CameraFeed\Test-118.jpg
# Processing image CameraFeed\Test-119.jpg
# Processing image CameraFeed\Test-120.jpg
# Processing image CameraFeed\Test-121.jpg
# Processing image CameraFeed\Test-122.jpg
# Processing image CameraFeed\Test-123.jpg
# Processing image CameraFeed\Test-124.jpg
# Processing image CameraFeed\Test-125.jpg
# Processing image CameraFeed\Test-126.jpg
# Valid image: CameraFeed\Test-126.jpg
# Processing image CameraFeed\Test-127.jpg
# Valid image: CameraFeed\Test-127.jpg
# Processing image CameraFeed\Test-128.jpg
# Valid image: CameraFeed\Test-128.jpg
# Processing image CameraFeed\Test-129.jpg
# Valid image: CameraFeed\Test-129.jpg
# Processing image CameraFeed\Test-130.jpg
# Valid image: CameraFeed\Test-130.jpg
# Processing image CameraFeed\Test-131.jpg
# Valid image: CameraFeed\Test-131.jpg
# Processing image CameraFeed\Test-132.jpg
# Valid image: CameraFeed\Test-132.jpg
# Processing image CameraFeed\Test-133.jpg
# Valid image: CameraFeed\Test-133.jpg
# Processing image CameraFeed\Test-134.jpg
# Processing image CameraFeed\Test-135.jpg
# Valid image: CameraFeed\Test-135.jpg
# Processing image CameraFeed\Test-136.jpg
# Valid image: CameraFeed\Test-136.jpg
# Processing image CameraFeed\Test-137.jpg
# Valid image: CameraFeed\Test-137.jpg
# Processing image CameraFeed\Test-138.jpg
# Valid image: CameraFeed\Test-138.jpg
# Processing image CameraFeed\Test-139.jpg
# Valid image: CameraFeed\Test-139.jpg
# Processing image CameraFeed\Test-14.jpg
# Processing image CameraFeed\Test-140.jpg
# Valid image: CameraFeed\Test-140.jpg
# Processing image CameraFeed\Test-141.jpg
# Valid image: CameraFeed\Test-141.jpg
# Processing image CameraFeed\Test-142.jpg
# Valid image: CameraFeed\Test-142.jpg
# Processing image CameraFeed\Test-143.jpg
# Valid image: CameraFeed\Test-143.jpg
# Processing image CameraFeed\Test-144.jpg
# Valid image: CameraFeed\Test-144.jpg
# Processing image CameraFeed\Test-145.jpg
# Processing image CameraFeed\Test-146.jpg
# Valid image: CameraFeed\Test-146.jpg
# Processing image CameraFeed\Test-147.jpg
# Valid image: CameraFeed\Test-147.jpg
# Processing image CameraFeed\Test-148.jpg
# Valid image: CameraFeed\Test-148.jpg
# Processing image CameraFeed\Test-149.jpg
# Valid image: CameraFeed\Test-149.jpg
# Processing image CameraFeed\Test-15.jpg
# Processing image CameraFeed\Test-150.jpg
# Valid image: CameraFeed\Test-150.jpg
# Processing image CameraFeed\Test-151.jpg
# Valid image: CameraFeed\Test-151.jpg
# Processing image CameraFeed\Test-152.jpg
# Valid image: CameraFeed\Test-152.jpg
# Processing image CameraFeed\Test-153.jpg
# Processing image CameraFeed\Test-154.jpg
# Processing image CameraFeed\Test-155.jpg
# Valid image: CameraFeed\Test-155.jpg
# Processing image CameraFeed\Test-156.jpg
# Processing image CameraFeed\Test-157.jpg
# Valid image: CameraFeed\Test-157.jpg
# Processing image CameraFeed\Test-158.jpg
# Valid image: CameraFeed\Test-158.jpg
# Processing image CameraFeed\Test-159.jpg
# Valid image: CameraFeed\Test-159.jpg
# Processing image CameraFeed\Test-16.jpg
# Processing image CameraFeed\Test-160.jpg
# Processing image CameraFeed\Test-161.jpg
# Processing image CameraFeed\Test-162.jpg
# Processing image CameraFeed\Test-163.jpg
# Processing image CameraFeed\Test-164.jpg
# Valid image: CameraFeed\Test-164.jpg
# Processing image CameraFeed\Test-165.jpg
# Valid image: CameraFeed\Test-165.jpg
# Processing image CameraFeed\Test-166.jpg
# Valid image: CameraFeed\Test-166.jpg
# Processing image CameraFeed\Test-167.jpg
# Valid image: CameraFeed\Test-167.jpg
# Processing image CameraFeed\Test-168.jpg
# Valid image: CameraFeed\Test-168.jpg
# Processing image CameraFeed\Test-169.jpg
# Processing image CameraFeed\Test-17.jpg
# Processing image CameraFeed\Test-170.jpg
# Processing image CameraFeed\Test-171.jpg
# Valid image: CameraFeed\Test-171.jpg
# Processing image CameraFeed\Test-172.jpg
# Processing image CameraFeed\Test-173.jpg
# Processing image CameraFeed\Test-174.jpg
# Processing image CameraFeed\Test-18.jpg
# Processing image CameraFeed\Test-19.jpg
# Processing image CameraFeed\Test-20.jpg
# Processing image CameraFeed\Test-21.jpg
# Valid image: CameraFeed\Test-21.jpg
# Processing image CameraFeed\Test-22.jpg
# Valid image: CameraFeed\Test-22.jpg
# Processing image CameraFeed\Test-23.jpg
# Valid image: CameraFeed\Test-23.jpg
# Processing image CameraFeed\Test-24.jpg
# Valid image: CameraFeed\Test-24.jpg
# Processing image CameraFeed\Test-25.jpg
# Processing image CameraFeed\Test-26.jpg
# Processing image CameraFeed\Test-27.jpg
# Processing image CameraFeed\Test-28.jpg
# Processing image CameraFeed\Test-29.jpg
# Processing image CameraFeed\Test-3.jpg
# Valid image: CameraFeed\Test-3.jpg
# Processing image CameraFeed\Test-30.jpg
# Valid image: CameraFeed\Test-30.jpg
# Processing image CameraFeed\Test-31.jpg
# Valid image: CameraFeed\Test-31.jpg
# Processing image CameraFeed\Test-32.jpg
# Valid image: CameraFeed\Test-32.jpg
# Processing image CameraFeed\Test-33.jpg
# Valid image: CameraFeed\Test-33.jpg
# Processing image CameraFeed\Test-34.jpg
# Valid image: CameraFeed\Test-34.jpg
# Processing image CameraFeed\Test-35.jpg
# Valid image: CameraFeed\Test-35.jpg
# Processing image CameraFeed\Test-36.jpg
# Valid image: CameraFeed\Test-36.jpg
# Processing image CameraFeed\Test-37.jpg
# Valid image: CameraFeed\Test-37.jpg
# Processing image CameraFeed\Test-38.jpg
# Valid image: CameraFeed\Test-38.jpg
# Processing image CameraFeed\Test-39.jpg
# Valid image: CameraFeed\Test-39.jpg
# Processing image CameraFeed\Test-4.jpg
# Valid image: CameraFeed\Test-4.jpg
# Processing image CameraFeed\Test-40.jpg
# Valid image: CameraFeed\Test-40.jpg
# Processing image CameraFeed\Test-41.jpg
# Valid image: CameraFeed\Test-41.jpg
# Processing image CameraFeed\Test-42.jpg
# Valid image: CameraFeed\Test-42.jpg
# Processing image CameraFeed\Test-43.jpg
# Valid image: CameraFeed\Test-43.jpg
# Processing image CameraFeed\Test-44.jpg
# Valid image: CameraFeed\Test-44.jpg
# Processing image CameraFeed\Test-45.jpg
# Valid image: CameraFeed\Test-45.jpg
# Processing image CameraFeed\Test-46.jpg
# Valid image: CameraFeed\Test-46.jpg
# Processing image CameraFeed\Test-47.jpg
# Valid image: CameraFeed\Test-47.jpg
# Processing image CameraFeed\Test-48.jpg
# Valid image: CameraFeed\Test-48.jpg
# Processing image CameraFeed\Test-49.jpg
# Valid image: CameraFeed\Test-49.jpg
# Processing image CameraFeed\Test-5.jpg
# Valid image: CameraFeed\Test-5.jpg
# Processing image CameraFeed\Test-50.jpg
# Valid image: CameraFeed\Test-50.jpg
# Processing image CameraFeed\Test-51.jpg
# Processing image CameraFeed\Test-52.jpg
# Processing image CameraFeed\Test-53.jpg
# Processing image CameraFeed\Test-54.jpg
# Processing image CameraFeed\Test-55.jpg
# Valid image: CameraFeed\Test-55.jpg
# Processing image CameraFeed\Test-56.jpg
# Processing image CameraFeed\Test-57.jpg
# Processing image CameraFeed\Test-58.jpg
# Processing image CameraFeed\Test-59.jpg
# Valid image: CameraFeed\Test-59.jpg
# Processing image CameraFeed\Test-6.jpg
# Valid image: CameraFeed\Test-6.jpg
# Processing image CameraFeed\Test-60.jpg
# Processing image CameraFeed\Test-61.jpg
# Valid image: CameraFeed\Test-61.jpg
# Processing image CameraFeed\Test-62.jpg
# Valid image: CameraFeed\Test-62.jpg
# Processing image CameraFeed\Test-63.jpg
# Valid image: CameraFeed\Test-63.jpg
# Processing image CameraFeed\Test-64.jpg
# Processing image CameraFeed\Test-65.jpg
# Processing image CameraFeed\Test-66.jpg
# Processing image CameraFeed\Test-67.jpg
# Processing image CameraFeed\Test-68.jpg
# Processing image CameraFeed\Test-7.jpg
# Valid image: CameraFeed\Test-7.jpg
# Processing image CameraFeed\Test-75.jpg
# Valid image: CameraFeed\Test-75.jpg
# Processing image CameraFeed\Test-76.jpg
# Processing image CameraFeed\Test-77.jpg
# Processing image CameraFeed\Test-78.jpg
# Valid image: CameraFeed\Test-78.jpg
# Processing image CameraFeed\Test-79.jpg
# Valid image: CameraFeed\Test-79.jpg
# Processing image CameraFeed\Test-8.jpg
# Valid image: CameraFeed\Test-8.jpg
# Processing image CameraFeed\Test-80.jpg
# Valid image: CameraFeed\Test-80.jpg
# Processing image CameraFeed\Test-81.jpg
# Valid image: CameraFeed\Test-81.jpg
# Processing image CameraFeed\Test-82.jpg
# Valid image: CameraFeed\Test-82.jpg
# Processing image CameraFeed\Test-86.jpg
# Processing image CameraFeed\Test-87.jpg
# Processing image CameraFeed\Test-88.jpg
# Processing image CameraFeed\Test-89.jpg
# Valid image: CameraFeed\Test-89.jpg
# Processing image CameraFeed\Test-9.jpg
# Valid image: CameraFeed\Test-9.jpg
# Processing image CameraFeed\Test-90.jpg
# Processing image CameraFeed\Test-91.jpg
# Processing image CameraFeed\Test-92.jpg
# Valid image: CameraFeed\Test-92.jpg
# Processing image CameraFeed\Test-93.jpg
# Valid image: CameraFeed\Test-93.jpg
# Processing image CameraFeed\Test-94.jpg
# Valid image: CameraFeed\Test-94.jpg
# Processing image CameraFeed\Test-95.jpg
# Valid image: CameraFeed\Test-95.jpg
# Processing image CameraFeed\Test-96.jpg
# Valid image: CameraFeed\Test-96.jpg
# Processing image CameraFeed\Test-97.jpg
# Valid image: CameraFeed\Test-97.jpg
# Processing image CameraFeed\Test-98.jpg
# Valid image: CameraFeed\Test-98.jpg
# Processing image CameraFeed\Test-99.jpg
# Valid image: CameraFeed\Test-99.jpg
# Found 103 valid images for calibration
# DIM=(800, 800)
# K=np.array([[388.64730611958856, 0.0, 449.47094620687164], [0.0, 388.91362511113493, 343.0733743508866], [0.0, 0.0, 1.0]])
# D=np.array([[-0.06028128941954454], [-0.0017907871903818239], [-0.08044438350110109], [0.101569106782424]])

# %%
### undistort with parameters from fisheye calibration

# insert the output of fisheye calibration step
DIM=(800, 800)
K=np.array([[351.6318033232932, 0.0, 450.4607527123814], [0.0, 351.7439651791754, 391.2576486450391], [0.0, 0.0, 1.0]])
D=np.array([[-0.170592708935433], [0.5324235902617314], [-1.5452235955907878], [1.4793950832426657]])




def undistort(img_path, balance=0.0, dim2=None, dim3=None):
    
    img = cv2.imread(img_path)
    
    dim1 = img.shape[:2][::-1]  #dim1 is the dimension of input image to un-distort
    
   # assert dim1[0]/dim1[1] == DIM[0]/DIM[1], "Image to undistort needs to have same aspect ratio as the ones used in calibration"
    
    if not dim2:
        dim2 = dim1
    if not dim3:
        dim3 = dim1
        
        
    scaled_K = K * dim1[0] / DIM[0]  # The values of K is to scale with image dimension.
    scaled_K[2][2] = 1.0  # Except that K[2][2] is always 1.0
    
    # This is how scaled_K, dim2 and balance are used to determine the final K used to un-distort image. OpenCV document failed to make this clear!
    new_K = cv2.fisheye.estimateNewCameraMatrixForUndistortRectify(scaled_K, D, dim2, np.eye(3), balance=balance)
    map1, map2 = cv2.fisheye.initUndistortRectifyMap(scaled_K, D, np.eye(3), new_K, dim3, cv2.CV_16SC2)
    undistorted_img = cv2.remap(img, map1, map2, interpolation=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT)
    
    cv2.imshow("distorted", img)
    cv2.imshow("undistorted", undistorted_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    
    
    
    
if __name__ == '__main__':
    undistort('TestFeed\Test-12.jpg', 1.0, (800,800), (800, 800))
    #for p in sys.argv[1:]:
    #    undistort(p)
